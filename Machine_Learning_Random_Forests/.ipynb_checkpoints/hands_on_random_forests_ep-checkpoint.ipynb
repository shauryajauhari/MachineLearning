# %% [markdown]
# # Decision Trees and Random Forests: Application for Enhancer Prediction

# %% [markdown]
# Shaurya Jauhari (Email: shauryajauhari@gzhmu.edu.cn)

# %% [markdown]
# Welcome to the second workshop in the series of **Machine Learning Fundamentals**. In this session, we shall explore the theory of **Decision Trees** and scale it to the broader concept of **Random Forests**. Decision trees epitomize the divide and conquer strategy to accomplish classification tasks (although they could also be implemented for regression chores as well)(Quinlan 1986, Rokach 2005). From the previous session on **Logistic Regression**, you may recall that if the response variable is catergorical in nature (factors in R), we aim classification, or else, if the response variable is continuous, it denotes regression. Classification and regression methodologies are both categorized under supervised machine learning. The theme of machine learning was realized in 1950s and since then, coupled with the data deluge and upheaval in computational prowess, has exhibited stronghold in data analysis domain (See figure below).

# %% [markdown]
# ![Machine Learning Genesis](./ML_Genesis.png)

# %% [markdown]
# In order to appreciate the concept of random forests, it is incumbent to learn about decision trees. A decision tree is the unit of random forest.

# %% [markdown]
# There is also an added understanding about dimensionality reduction in decision trees (and random forests as well). Recollecting the same concept in logistic regression, the idea was to penalize "non-performing" features by reducing their coefficients close to(alpha=0:Ridge) or equal to zero(alpha=1:Lasso)(there is also a provision for replicating the objective of train-test data partitioning, i.e. cross-validation). In decision trees, entropy, information gain, variance-bias, chi-square coefficients, gini-index, etc. parameters are optionally calculated to ascertain the best attribute to split/ partition the tree. It is crucial to engender the tree a definitive structure, else the curse of biasness in decision trees for continuous and nominal data comes to play.

# %% [markdown]
# Random forests enlighten on the dogma of democracy, i.e. *majority wins*. Decision Trees are rudimentary classification algorithms that, at a low-level, are synonymous to *if-then* conditional statements in programming languages. They follow the strategy of iterative recursion, and intuitively the leaf nodes hold the final verdict. The highest aggregate from all leaf nodes (terminals) is graded as the output of that decision tree.
#
# In this module, we shall delve into creation of basic decision trees to have an understanding of it. For the purpose, we shall load the package **party** and make use of the function **ctree()** to calculate and analyze decision trees. Furthermore, we shall require the packages **rpart**, **party**, **randomForest** as well. Let's load them up.

# %% [markdown]
# # Decision Trees

# %% [markdown]
# ## Package Installation and Loading

# %%
install.packages("party", dependencies = TRUE, repos = "https://mirrors.tuna.tsinghua.edu.cn/CRAN/")
install.packages("rpart", dependencies = TRUE, repos = "https://mirrors.tuna.tsinghua.edu.cn/CRAN/")
install.packages("rpart.plot", dependencies = TRUE, repos = "https://mirrors.tuna.tsinghua.edu.cn/CRAN/")
library(party)
library(rpart)
library(rpart.plot)
# Out:
# Loading required package: grid
#
# Loading required package: mvtnorm
#
# Loading required package: modeltools
#
# Loading required package: stats4
#
# Loading required package: strucchange
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Loading required package: sandwich

# %% [markdown]
# Let us now, pick up a dataset. The dataset pertains to the soft computation of the **enhancer prediction** module in bioinformatics. We certainly take into cognizance the biological implications about enhancer regions (See figure below).
# Certain known classes of proteins/ cis-regulatory elements called Transcription Factors (TFs) and Transcription Co-Activators (TCoAs) are programmed to bind to regions in the genome called *Enhancers*, that remotely orchestrate the phenomena of gene regulation. They are at a distal location to the *Promoters*, regions associated with genes and respective Transcription Start Sites (TSS). On stimulus from TFs, the enhancer and promoter sequences reciprocate and actuate the transcription machinery.

# %% [markdown]
# ![Enhancer Prediction Basis](./WorkFlow_Illustration.jpg)

# %% [markdown]
# ## Dataset handling

# %% [markdown]
# For use in this session, we have chosen a compound dataset from the [here](https://nbviewer.jupyter.org/github/shauryajauhari/Machine_Learning/blob/master/Machine_Learning_Deep_Learning/enhancer_prediction_dataset_protocol.ipynb).

# %%
epdata <- readRDS("../Machine_Learning_Deep_Learning/predictionData.rds")
rownames(epdata) <- c()

epdata <- epdata[,4:8]
colnames(epdata)[1:4] <- c("reads_h3k27ac", "reads_h3k4me1", "reads_h3k4me2", "reads_h3k4me3")

epdata$class <- as.numeric(as.factor(epdata$class))-1

# %%
# Let's look at the data.

head(epdata)
# Out:
#   reads_h3k27ac reads_h3k4me1 reads_h3k4me2 reads_h3k4me3 class
# 1 0             0.00000       0             0             1
# 2 0             0.00000       0             0             1
# 3 0             0.00000       0             0             1
# 4 0             0.00000       0             0             1
# 5 0             0.11165       0             0             1
# 6 0             0.00000       0             0             1

# %% [markdown]
# ### Deploying Tree Models
# #### 'party' package

# %% [markdown]
# Let us now partition the data into test and validation cases. We shall be assuming 80% of the data for training and 20% for testing tasks.

# %%
set.seed(3)
data_partition <- sample(2, nrow(epdata), replace = TRUE, prob = c(0.8,0.2))
train <- epdata[data_partition==1,]
test <- epdata[data_partition==2,]

# %% [markdown]
# #### Exercise
# - Try data partitioning with a 70:30 split for training and testing examples. See if it makes any difference in the classification ahead.

# %%
data_partition1 <- sample(2, nrow(epdata), replace = TRUE, prob = c(0.7,0.3))

# %%
cat("We have",nrow(train),"training examples and",nrow(test),"for testing.")
# Out:
# We have 907911 training examples and 227315 for testing.

# %%
ep_tree <- ctree(class ~ reads_h3k27ac + reads_h3k4me3 + reads_h3k4me2 + reads_h3k4me1, data= train)
print(ep_tree)
# Out:
# 	 Conditional inference tree with 119 terminal nodes
#
# Response:  class
# Inputs:  reads_h3k27ac, reads_h3k4me3, reads_h3k4me2, reads_h3k4me1
# Number of observations:  907911
#
# 1) reads_h3k4me2 <= 0.7658814; criterion = 1, statistic = 6293.012
#   2) reads_h3k4me3 <= 0; criterion = 1, statistic = 234.268
#     3) reads_h3k27ac <= 0; criterion = 1, statistic = 8375.237
#       4) reads_h3k4me1 <= 0; criterion = 1, statistic = 3514.844
#         5) reads_h3k4me2 <= 0; criterion = 1, statistic = 1687.371
#           6)*  weights = 106297
#         5) reads_h3k4me2 > 0
#           7) reads_h3k4me2 <= 0.08509794; criterion = 0.991, statistic = 9.236
#             8)*  weights = 2440
#           7) reads_h3k4me2 > 0.08509794
#             9)*  weights = 624
#       4) reads_h3k4me1 > 0
#         10) reads_h3k4me1 <= 0.11165; criterion = 0.998, statistic = 12.254
#           11)*  weights = 4156
#         10) reads_h3k4me1 > 0.11165
#           12)*  weights = 2442
#     3) reads_h3k27ac > 0
#       13) reads_h3k4me2 <= 0.1701959; criterion = 1, statistic = 528.762
#         14) reads_h3k27ac <= 0.4341858; criterion = 1, statistic = 70.82
#           15) reads_h3k4me2 <= 0; criterion = 0.996, statistic = 11.031
#             16) reads_h3k4me1 <= 0; criterion = 1, statistic = 24.461
#               17) reads_h3k27ac <= 0.0723643; criterion = 1, statistic = 39.69
#                 18)*  weights = 4815
#               17) reads_h3k27ac > 0.0723643
#                 19)*  weights = 4080
#             16) reads_h3k4me1 > 0
#               20)*  weights = 14737
#           15) reads_h3k4me2 > 0
#             21) reads_h3k4me1 <= 0.4466001; criterion = 0.994, statistic = 10.065
#               22)*  weights = 28517
#             21) reads_h3k4me1 > 0.4466001
#               23)*  weights = 3675
#         14) reads_h3k27ac > 0.4341858
#           24) reads_h3k4me2 <= 0.08509794; criterion = 0.998, statistic = 12.396
#             25) reads_h3k27ac <= 0.7960073; criterion = 0.954, statistic = 6.371
#               26) reads_h3k4me1 <= 0.2233001; criterion = 0.961, statistic = 6.671
#                 27)*  weights = 2614
#               26) reads_h3k4me1 > 0.2233001
#                 28)*  weights = 2494
#             25) reads_h3k27ac > 0.7960073
#               29)*  weights = 478
#           24) reads_h3k4me2 > 0.08509794
#             30)*  weights = 4405
#       13) reads_h3k4me2 > 0.1701959
#         31) reads_h3k27ac <= 0.5789144; criterion = 1, statistic = 146.924
#           32) reads_h3k27ac <= 0.3618215; criterion = 1, statistic = 17.413
#             33)*  weights = 11756
#           32) reads_h3k27ac > 0.3618215
#             34)*  weights = 8800
#         31) reads_h3k27ac > 0.5789144
#           35) reads_h3k4me1 <= 0.7815502; criterion = 1, statistic = 38.115
#             36) reads_h3k4me2 <= 0.5956856; criterion = 1, statistic = 19.532
#               37) reads_h3k27ac <= 0.7960073; criterion = 0.986, statistic = 8.557
#                 38)*  weights = 4040
#               37) reads_h3k27ac > 0.7960073
#                 39)*  weights = 2194
#             36) reads_h3k4me2 > 0.5956856
#               40)*  weights = 653
#           35) reads_h3k4me1 > 0.7815502
#             41)*  weights = 2416
#   2) reads_h3k4me3 > 0
#     42) reads_h3k27ac <= 0.4341858; criterion = 1, statistic = 6145.816
#       43) reads_h3k4me2 <= 0.1701959; criterion = 1, statistic = 1278.352
#         44) reads_h3k4me3 <= 0.1590257; criterion = 1, statistic = 235.799
#           45) reads_h3k4me2 <= 0.08509794; criterion = 1, statistic = 124.222
#             46) reads_h3k27ac <= 0.2170929; criterion = 1, statistic = 35.662
#               47) reads_h3k27ac <= 0; criterion = 0.98, statistic = 7.869
#                 48) reads_h3k4me1 <= 0; criterion = 1, statistic = 35.977
#                   49)*  weights = 4490
#                 48) reads_h3k4me1 > 0
#                   50)*  weights = 4452
#               47) reads_h3k27ac > 0
#                 51) reads_h3k4me2 <= 0; criterion = 0.999, statistic = 12.681
#                   52)*  weights = 21743
#                 51) reads_h3k4me2 > 0
#                   53)*  weights = 21474
#             46) reads_h3k27ac > 0.2170929
#               54) reads_h3k4me1 <= 0.11165; criterion = 1, statistic = 31.028
#                 55) reads_h3k4me2 <= 0; criterion = 0.998, statistic = 12.228
#                   56)*  weights = 5242
#                 55) reads_h3k4me2 > 0
#                   57)*  weights = 7012
#               54) reads_h3k4me1 > 0.11165
#                 58) reads_h3k27ac <= 0.3618215; criterion = 0.999, statistic = 13.964
#                   59)*  weights = 16526
#                 58) reads_h3k27ac > 0.3618215
#                   60)*  weights = 6270
#           45) reads_h3k4me2 > 0.08509794
#             61) reads_h3k27ac <= 0.1447286; criterion = 1, statistic = 31.31
#               62) reads_h3k4me3 <= 0.07951283; criterion = 0.975, statistic = 7.475
#                 63)*  weights = 5615
#               62) reads_h3k4me3 > 0.07951283
#                 64)*  weights = 3611
#             61) reads_h3k27ac > 0.1447286
#               65) reads_h3k4me1 <= 0.3349501; criterion = 1, statistic = 18.598
#                 66)*  weights = 17837
#               65) reads_h3k4me1 > 0.3349501
#                 67)*  weights = 7787
#         44) reads_h3k4me3 > 0.1590257
#           68) reads_h3k27ac <= 0.2170929; criterion = 1, statistic = 83.933
#             69) reads_h3k4me2 <= 0.08509794; criterion = 1, statistic = 27.621
#               70) reads_h3k4me1 <= 0.3349501; criterion = 0.98, statistic = 7.833
#                 71)*  weights = 9777
#               70) reads_h3k4me1 > 0.3349501
#                 72)*  weights = 2363
#             69) reads_h3k4me2 > 0.08509794
#               73) reads_h3k4me3 <= 0.3975641; criterion = 1, statistic = 15.464
#                 74)*  weights = 5368
#               73) reads_h3k4me3 > 0.3975641
#                 75)*  weights = 309
#           68) reads_h3k27ac > 0.2170929
#             76) reads_h3k4me1 <= 0.3349501; criterion = 1, statistic = 30.606
#               77) reads_h3k4me2 <= 0; criterion = 1, statistic = 16.055
#                 78)*  weights = 4091
#               77) reads_h3k4me2 > 0
#                 79) reads_h3k4me3 <= 0.2385385; criterion = 0.995, statistic = 10.394
#                   80)*  weights = 8152
#                 79) reads_h3k4me3 > 0.2385385
#                   81)*  weights = 6773
#             76) reads_h3k4me1 > 0.3349501
#               82)*  weights = 8568
#       43) reads_h3k4me2 > 0.1701959
#         83) reads_h3k4me3 <= 0.2385385; criterion = 1, statistic = 146.151
#           84) reads_h3k4me1 <= 0.4466001; criterion = 1, statistic = 96.058
#             85) reads_h3k27ac <= 0.2170929; criterion = 1, statistic = 43.06
#               86) reads_h3k4me2 <= 0.2552938; criterion = 0.95, statistic = 6.205
#                 87)*  weights = 8906
#               86) reads_h3k4me2 > 0.2552938
#                 88) reads_h3k27ac <= 0.0723643; criterion = 0.989, statistic = 9.034
#                   89)*  weights = 1435
#                 88) reads_h3k27ac > 0.0723643
#                   90)*  weights = 6776
#             85) reads_h3k27ac > 0.2170929
#               91) reads_h3k4me2 <= 0.4254897; criterion = 1, statistic = 16.702
#                 92) reads_h3k4me3 <= 0.07951283; criterion = 0.957, statistic = 6.469
#                   93)*  weights = 10953
#                 92) reads_h3k4me3 > 0.07951283
#                   94)*  weights = 19051
#               91) reads_h3k4me2 > 0.4254897
#                 95)*  weights = 6087
#           84) reads_h3k4me1 > 0.4466001
#             96) reads_h3k4me2 <= 0.3403918; criterion = 1, statistic = 14.797
#               97)*  weights = 11892
#             96) reads_h3k4me2 > 0.3403918
#               98)*  weights = 10869
#         83) reads_h3k4me3 > 0.2385385
#           99) reads_h3k4me2 <= 0.2552938; criterion = 1, statistic = 28.292
#             100)*  weights = 6855
#           99) reads_h3k4me2 > 0.2552938
#             101) reads_h3k4me1 <= 0.5582502; criterion = 1, statistic = 16.935
#               102) reads_h3k4me3 <= 0.6361026; criterion = 0.994, statistic = 10.139
#                 103)*  weights = 11523
#               102) reads_h3k4me3 > 0.6361026
#                 104)*  weights = 422
#             101) reads_h3k4me1 > 0.5582502
#               105)*  weights = 5050
#     42) reads_h3k27ac > 0.4341858
#       106) reads_h3k4me2 <= 0.2552938; criterion = 1, statistic = 1388.322
#         107) reads_h3k27ac <= 0.723643; criterion = 1, statistic = 315.379
#           108) reads_h3k4me3 <= 0.2385385; criterion = 1, statistic = 105.154
#             109) reads_h3k4me1 <= 0.2233001; criterion = 1, statistic = 48.778
#               110) reads_h3k4me2 <= 0.08509794; criterion = 0.999, statistic = 12.841
#                 111) reads_h3k4me3 <= 0.07951283; criterion = 0.992, statistic = 9.605
#                   112)*  weights = 4383
#                 111) reads_h3k4me3 > 0.07951283
#                   113)*  weights = 7077
#               110) reads_h3k4me2 > 0.08509794
#                 114)*  weights = 16190
#             109) reads_h3k4me1 > 0.2233001
#               115) reads_h3k4me2 <= 0.1701959; criterion = 0.997, statistic = 11.092
#                 116)*  weights = 24490
#               115) reads_h3k4me2 > 0.1701959
#                 117)*  weights = 12915
#           108) reads_h3k4me3 > 0.2385385
#             118) reads_h3k27ac <= 0.5789144; criterion = 0.999, statistic = 12.941
#               119)*  weights = 11447
#             118) reads_h3k27ac > 0.5789144
#               120) reads_h3k4me2 <= 0.1701959; criterion = 0.996, statistic = 10.757
#                 121)*  weights = 5165
#               120) reads_h3k4me2 > 0.1701959
#                 122)*  weights = 3529
#         107) reads_h3k27ac > 0.723643
#           123) reads_h3k27ac <= 0.9407359; criterion = 1, statistic = 43.447
#             124) reads_h3k4me2 <= 0.08509794; criterion = 1, statistic = 16.074
#               125)*  weights = 6025
#             124) reads_h3k4me2 > 0.08509794
#               126) reads_h3k4me1 <= 0.5582502; criterion = 0.955, statistic = 6.403
#                 127)*  weights = 12394
#               126) reads_h3k4me1 > 0.5582502
#                 128)*  weights = 4669
#           123) reads_h3k27ac > 0.9407359
#             129) reads_h3k4me2 <= 0.08509794; criterion = 1, statistic = 19.818
#               130) reads_h3k4me3 <= 0.477077; criterion = 0.996, statistic = 11.059
#                 131)*  weights = 1898
#               130) reads_h3k4me3 > 0.477077
#                 132)*  weights = 65
#             129) reads_h3k4me2 > 0.08509794
#               133)*  weights = 8039
#       106) reads_h3k4me2 > 0.2552938
#         134) reads_h3k27ac <= 0.7960073; criterion = 1, statistic = 440.308
#           135) reads_h3k4me1 <= 0.4466001; criterion = 1, statistic = 140.55
#             136) reads_h3k4me3 <= 0.3180513; criterion = 1, statistic = 52.896
#               137) reads_h3k27ac <= 0.5789144; criterion = 1, statistic = 19.919
#                 138)*  weights = 19805
#               137) reads_h3k27ac > 0.5789144
#                 139) reads_h3k4me2 <= 0.5105876; criterion = 0.992, statistic = 9.435
#                   140)*  weights = 17463
#                 139) reads_h3k4me2 > 0.5105876
#                   141)*  weights = 5406
#             136) reads_h3k4me3 > 0.3180513
#               142)*  weights = 9981
#           135) reads_h3k4me1 > 0.4466001
#             143) reads_h3k4me3 <= 0.07951283; criterion = 1, statistic = 41.925
#               144) reads_h3k4me2 <= 0.5956856; criterion = 0.97, statistic = 7.127
#                 145)*  weights = 7342
#               144) reads_h3k4me2 > 0.5956856
#                 146)*  weights = 1667
#             143) reads_h3k4me3 > 0.07951283
#               147) reads_h3k27ac <= 0.6512787; criterion = 1, statistic = 22.179
#                 148) reads_h3k4me2 <= 0.5105876; criterion = 1, statistic = 18.859
#                   149)*  weights = 16126
#                 148) reads_h3k4me2 > 0.5105876
#                   150)*  weights = 9780
#               147) reads_h3k27ac > 0.6512787
#                 151) reads_h3k4me1 <= 0.7815502; criterion = 0.999, statistic = 14.174
#                   152)*  weights = 8882
#                 151) reads_h3k4me1 > 0.7815502
#                   153)*  weights = 9556
#         134) reads_h3k27ac > 0.7960073
#           154) reads_h3k4me1 <= 0.6699002; criterion = 1, statistic = 123.443
#             155) reads_h3k27ac <= 1.085464; criterion = 1, statistic = 37.725
#               156) reads_h3k4me2 <= 0.3403918; criterion = 0.983, statistic = 8.21
#                 157)*  weights = 6463
#               156) reads_h3k4me2 > 0.3403918
#                 158) reads_h3k27ac <= 0.9407359; criterion = 0.99, statistic = 9.219
#                   159)*  weights = 12815
#                 158) reads_h3k27ac > 0.9407359
#                   160)*  weights = 7548
#             155) reads_h3k27ac > 1.085464
#               161) reads_h3k4me2 <= 0.4254897; criterion = 0.993, statistic = 9.885
#                 162)*  weights = 3493
#               161) reads_h3k4me2 > 0.4254897
#                 163)*  weights = 5922
#           154) reads_h3k4me1 > 0.6699002
#             164) reads_h3k4me1 <= 1.22815; criterion = 1, statistic = 20.196
#               165) reads_h3k4me2 <= 0.3403918; criterion = 0.99, statistic = 9.103
#                 166)*  weights = 2888
#               165) reads_h3k4me2 > 0.3403918
#                 167)*  weights = 18104
#             164) reads_h3k4me1 > 1.22815
#               168)*  weights = 15839
# 1) reads_h3k4me2 > 0.7658814
#   169) reads_h3k4me3 <= 7.156155; criterion = 1, statistic = 2312.654
#     170) reads_h3k4me1 <= 2.233001; criterion = 1, statistic = 424.25
#       171) reads_h3k4me3 <= 0.3975641; criterion = 1, statistic = 60.726
#         172) reads_h3k4me1 <= 1.22815; criterion = 1, statistic = 49.06
#           173) reads_h3k27ac <= 1.0131; criterion = 1, statistic = 23.225
#             174) reads_h3k27ac <= 0.5065501; criterion = 1, statistic = 24.685
#               175)*  weights = 4539
#             174) reads_h3k27ac > 0.5065501
#               176) reads_h3k4me3 <= 0.07951283; criterion = 0.963, statistic = 6.759
#                 177)*  weights = 2439
#               176) reads_h3k4me3 > 0.07951283
#                 178)*  weights = 13187
#           173) reads_h3k27ac > 1.0131
#             179) reads_h3k27ac <= 2.388022; criterion = 1, statistic = 21.587
#               180)*  weights = 9376
#             179) reads_h3k27ac > 2.388022
#               181)*  weights = 462
#         172) reads_h3k4me1 > 1.22815
#           182) reads_h3k27ac <= 0.6512787; criterion = 0.996, statistic = 10.761
#             183)*  weights = 2904
#           182) reads_h3k27ac > 0.6512787
#             184) reads_h3k27ac <= 4.703679; criterion = 1, statistic = 35.263
#               185)*  weights = 16843
#             184) reads_h3k27ac > 4.703679
#               186)*  weights = 186
#       171) reads_h3k4me3 > 0.3975641
#         187) reads_h3k27ac <= 2.315658; criterion = 1, statistic = 35.648
#           188) reads_h3k27ac <= 1.302557; criterion = 1, statistic = 17.221
#             189) reads_h3k4me3 <= 4.611744; criterion = 1, statistic = 24.208
#               190) reads_h3k4me1 <= 1.45145; criterion = 0.957, statistic = 6.477
#                 191)*  weights = 15129
#               190) reads_h3k4me1 > 1.45145
#                 192)*  weights = 5392
#             189) reads_h3k4me3 > 4.611744
#               193)*  weights = 852
#           188) reads_h3k27ac > 1.302557
#             194)*  weights = 7429
#         187) reads_h3k27ac > 2.315658
#           195) reads_h3k27ac <= 4.848408; criterion = 0.988, statistic = 8.77
#             196)*  weights = 2400
#           195) reads_h3k27ac > 4.848408
#             197) reads_h3k4me1 <= 1.786401; criterion = 0.976, statistic = 7.517
#               198)*  weights = 439
#             197) reads_h3k4me1 > 1.786401
#               199)*  weights = 378
#     170) reads_h3k4me1 > 2.233001
#       200) reads_h3k4me1 <= 6.475702; criterion = 1, statistic = 93.013
#         201) reads_h3k27ac <= 6.150965; criterion = 1, statistic = 29.676
#           202) reads_h3k4me3 <= 5.486385; criterion = 1, statistic = 29.094
#             203) reads_h3k4me1 <= 4.689301; criterion = 1, statistic = 15.453
#               204)*  weights = 24298
#             203) reads_h3k4me1 > 4.689301
#               205)*  weights = 4308
#           202) reads_h3k4me3 > 5.486385
#             206) reads_h3k27ac <= 3.980036; criterion = 1, statistic = 18.16
#               207)*  weights = 657
#             206) reads_h3k27ac > 3.980036
#               208)*  weights = 36
#         201) reads_h3k27ac > 6.150965
#           209) reads_h3k4me2 <= 6.892933; criterion = 1, statistic = 17.19
#             210)*  weights = 1206
#           209) reads_h3k4me2 > 6.892933
#             211)*  weights = 555
#       200) reads_h3k4me1 > 6.475702
#         212) reads_h3k4me2 <= 2.808232; criterion = 0.989, statistic = 8.956
#           213)*  weights = 1553
#         212) reads_h3k4me2 > 2.808232
#           214)*  weights = 2486
#   169) reads_h3k4me3 > 7.156155
#     215) reads_h3k4me3 <= 16.1411; criterion = 1, statistic = 340.198
#       216) reads_h3k27ac <= 13.09794; criterion = 1, statistic = 33.809
#         217) reads_h3k4me1 <= 4.131051; criterion = 1, statistic = 19.819
#           218)*  weights = 3924
#         217) reads_h3k4me1 > 4.131051
#           219)*  weights = 1343
#       216) reads_h3k27ac > 13.09794
#         220)*  weights = 94
#     215) reads_h3k4me3 > 16.1411
#       221) reads_h3k4me3 <= 24.33093; criterion = 1, statistic = 58.486
#         222) reads_h3k27ac <= 4.558951; criterion = 1, statistic = 22.922
#           223) reads_h3k4me1 <= 1.22815; criterion = 0.999, statistic = 14.335
#             224)*  weights = 598
#           223) reads_h3k4me1 > 1.22815
#             225) reads_h3k4me1 <= 5.135902; criterion = 0.974, statistic = 7.362
#               226) reads_h3k4me2 <= 22.12546; criterion = 0.955, statistic = 6.39
#                 227)*  weights = 1466
#               226) reads_h3k4me2 > 22.12546
#                 228) reads_h3k27ac <= 2.243293; criterion = 0.975, statistic = 7.47
#                   229)*  weights = 37
#                 228) reads_h3k27ac > 2.243293
#                   230)*  weights = 7
#             225) reads_h3k4me1 > 5.135902
#               231)*  weights = 234
#         222) reads_h3k27ac > 4.558951
#           232)*  weights = 627
#       221) reads_h3k4me3 > 24.33093
#         233) reads_h3k4me3 <= 43.09595; criterion = 1, statistic = 15.199
#           234)*  weights = 3814
#         233) reads_h3k4me3 > 43.09595
#           235) reads_h3k4me1 <= 1.1165; criterion = 0.983, statistic = 8.112
#             236)*  weights = 933
#           235) reads_h3k4me1 > 1.1165
#             237)*  weights = 1502

# %%
plot(ep_tree)
# Out:
# plot without title

# %% [markdown]
# It is a pretty dense tree to make sense of; especially from the visualization. The summary says that it has 237 overall nodes.

# %% [markdown]
# #### Exercise
# - Addtionally, the function ctree() offers flexibility in terms of defining parameters for classification via ctree_control() function. Look for attributes *mincriterion* and *minsplit*. The former denotes the confidence level (i.e. 1- probability value), while the latter signifies the minimum number of samples required for splitting a tree branch into two. The default values are 0.95 and 20 respectively. See if any alteration makes a difference.
# - They can be accessed via *controls*, i.e. ctree(formula,data,controls=ctree_control(mincriterion= , minsplit= ).
# - You may explore other attributes too.

# %%
tree_pred <- predict(ep_tree,test)
head(ifelse(tree_pred>0.5, "Non-Enhancer", "Enhancer"))
tree_pred <- ifelse(tree_pred>0.5, "1", "0")
# Out:
#      class
# [1,] Non-Enhancer
# [2,] Non-Enhancer
# [3,] Non-Enhancer
# [4,] Non-Enhancer
# [5,] Non-Enhancer
# [6,] Non-Enhancer

# %%
tree_pred_prob <- predict(ep_tree,test, type="prob")
head(tree_pred_prob)
# Out:
# [[1]]
# [1] 0.8760172
#
# [[2]]
# [1] 0.8760172
#
# [[3]]
# [1] 0.8760172
#
# [[4]]
# [1] 0.8760172
#
# [[5]]
# [1] 0.5769971
#
# [[6]]
# [1] 0.8760172

# %% [markdown]
# #### Misclassification Error

# %%
tab <- table(tree_pred, test$class)
print(tab)
# Out:
#
# tree_pred      0      1
#         0   5857   5822
#         1  73562 142074

# %%
accur <- 1 - sum(diag(tab))/sum(tab)
cat("The accuracy of the model is",accur*100,"%")
#print("\n")
ifelse(accur>90, print("Not bad."), print("Poor."))
# Out:
# The accuracy of the model is 34.92246 %[1] "Poor."
# [1] "Poor."

# %% [markdown]
# #### Exercise
# - What do you think the misclassification error will be like if the table is drawn for *train* data?

# %%
tree_pred1 <- predict(ep_tree,train)
head(ifelse(tree_pred1>0.5, "Non-Enhancer", "Enhancer"))
tree_pred1 <- ifelse(tree_pred1 > 0.5, "1", "0")

# training data

tab1 <- table(tree_pred1, train$class)
print(tab1)

accur <- 1 - sum(diag(tab1))/sum(tab1)
cat("The accuracy of the model is",accur*100,"%")

ifelse(accur>90, print("Not bad."), print("Poor."))
# Out:
#      class
# [1,] Non-Enhancer
# [2,] Non-Enhancer
# [3,] Non-Enhancer
# [4,] Non-Enhancer
# [5,] Non-Enhancer
# [6,] Non-Enhancer
#
# tree_pred1      0      1
#          0  23471  22710
#          1 292063 569667
# The accuracy of the model is 34.67003 %[1] "Poor."
# [1] "Poor."

# %% [markdown]
# #### 'rpart' package

# %%
ep_tree1 <- rpart(class ~ reads_h3k27ac + reads_h3k4me3 + reads_h3k4me2 + reads_h3k4me1, data= train)
print(ep_tree1)
# Out:
# n= 907911
#
# node), split, n, deviance, yval
#       * denotes terminal node
#
# 1) root 907911 205873.80 0.6524615
#   2) reads_h3k27ac>=0.03618215 779301 182665.40 0.6249139
#     4) reads_h3k4me2< 0.3829407 461542 112887.60 0.5735664 *
#     5) reads_h3k4me2>=0.3829407 317759  66793.43 0.6994955 *
#   3) reads_h3k27ac< 0.03618215 128610  19033.48 0.8193842 *

# %%
rpart.plot(ep_tree1)
# Out:
# plot without title

# %%
tree_pred2 <- predict(ep_tree1,test)
head(tree_pred2)
# Out:
#         2        15        16        19        28        37
# 0.8193842 0.8193842 0.8193842 0.8193842 0.8193842 0.8193842

# %% [markdown]
# An important point to consider is that the enhancers outnumber non-enhancers by a near-10 fold margin in the current dataset (as depicted below). This engenders a natural bias.

# %%
table(epdata$class)
# Out:
#      0      1
# 394953 740273

# %% [markdown]
# There is a complete contrast between the two trees drawn from *ctree()* and *rpart()* functions. The *ctree* uses a significance test procedure in order to select variables instead of selecting the variable that maximizes an information measure (e.g. Gini coefficient). Basically the methodology of both approaches is different; *rpart* is a CART algorithm, while *party* is a CHAID algorithm. (http://www.bzst.com/2006/10/classification-trees-cart-vs-chaid.html).

# %% [markdown]
# Next, we move to the more fuller concept, of Random Forests.

# %% [markdown]
# # Random Forests

# %% [markdown]
# Decision trees are accomodated inside Random Forests. This ensemble brings about variety in data classification and hence more robustness. This notion also helps in avoidance of overfitting. Random forests can deal with large number of features and selects them for constructing trees on the basis of importance. As we will see, they are easy to implement and have two free parameters to tune- (i) *ntree* signifying the number of trees (where default value is 500), and (ii) *mtry* denoting variables randomly selected for each split (default here sq(p) when classification is sought, and (p/3) when regression; p is the total number of features in the dataset)

# %% [markdown]
# ## Package Installation and Loading (randomForest)

# %%
install.packages("randomForest", dependencies = TRUE, repos = "https://mirrors.tuna.tsinghua.edu.cn/CRAN/")
install.packages("caret", dependencies = TRUE, repos = "https://mirrors.tuna.tsinghua.edu.cn/CRAN/")
library(randomForest)
library(caret)
# Out:
# randomForest 4.6-14
#
# Type rfNews() to see new features/changes/bug fixes.
#
# Loading required package: lattice
#
# Loading required package: ggplot2
#
#
# Attaching package: ‘ggplot2’
#
#
# The following object is masked from ‘package:randomForest’:
#
#     margin

# %% [markdown]
# There are basically three steps involved in construction of a Random Forest:
#     1. Draw *ntree* bootstrap samples.
#     2. For each bootstrap sample, grow a un-pruned tree by choosing best split based on a random sample of *mtry* predictors at each node.
#     3. Predict new daat using majority votes for classification, and average for regression based on *ntree* trees.

# %% [markdown]
# For application, we shall consider a subset of the data we used for decision trees. The random forests algorithm tend to consume greater in terms of computational resources.

# %%
## Let us work with a fraction of data.

set.seed(108)

epdata_sample <- epdata[sample(nrow(epdata), replace=F, size=0.01*nrow(epdata)),]
rownames(epdata_sample) <- c()
epdata_sample$class <- as.numeric(as.factor(epdata_sample$class))-1

## Data partitioning

set.seed(5)
data_partition <- sample(2, nrow(epdata_sample), replace = TRUE, prob = c(0.7,0.3))
train_sample <- epdata_sample[data_partition==1,]
test_sample <- epdata_sample[data_partition==2,]

# %%
# Execute random forest algorithm
rf1 <- randomForest(formula= class ~ reads_h3k27ac + reads_h3k4me3 + reads_h3k4me2 + reads_h3k4me1, 
                    data= train_sample,
                   proximity = TRUE,
                   ntree=500)
print(rf1)
# Out:
# Warning message in randomForest.default(m, y, ...):
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Call:
#  randomForest(formula = class ~ reads_h3k27ac + reads_h3k4me3 +      reads_h3k4me2 + reads_h3k4me1, data = train_sample, proximity = TRUE,      ntree = 500)
#                Type of random forest: regression
#                      Number of trees: 500
# No. of variables tried at each split: 1
#
#           Mean of squared residuals: 0.2173132
#                     % Var explained: 3.1

# %%
# Prediction and Confusion Matrix
p1<- predict(rf1,train_sample)
head(ifelse(p1>0.5, "Non-Enhancer", "Enhancer"))
p1 <- ifelse(p1>0.5, "1", "0")
confusionMatrix(as.factor(p1),as.factor(train_sample$class))
# Out:
#              1              2              4              5              7
# "Non-Enhancer" "Non-Enhancer" "Non-Enhancer" "Non-Enhancer" "Non-Enhancer"
#             10
# "Non-Enhancer"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction    0    1
#          0  705   98
#          1 1986 5136
#
#                Accuracy : 0.737
#                  95% CI : (0.7272, 0.7467)
#     No Information Rate : 0.6604
#     P-Value [Acc > NIR] : < 2.2e-16
#
#                   Kappa : 0.2932
#
#  Mcnemar's Test P-Value : < 2.2e-16
#
#             Sensitivity : 0.26198
#             Specificity : 0.98128
#          Pos Pred Value : 0.87796
#          Neg Pred Value : 0.72115
#              Prevalence : 0.33956
#          Detection Rate : 0.08896
#    Detection Prevalence : 0.10132
#       Balanced Accuracy : 0.62163
#
#        'Positive' Class : 0

# %%
p2<- predict(rf1,test_sample)
head(ifelse(p2>0.5, "Non-Enhancer", "Enhancer"))
p2 <- ifelse(p2>0.5, "1", "0")
confusionMatrix(as.factor(p2),as.factor(test_sample$class))
# Out:
#              3              6              8              9             18
# "Non-Enhancer" "Non-Enhancer" "Non-Enhancer" "Non-Enhancer" "Non-Enhancer"
#             20
# "Non-Enhancer"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction    0    1
#          0   90  111
#          1 1104 2122
#
#                Accuracy : 0.6455
#                  95% CI : (0.6292, 0.6615)
#     No Information Rate : 0.6516
#     P-Value [Acc > NIR] : 0.7798
#
#                   Kappa : 0.0318
#
#  Mcnemar's Test P-Value : <2e-16
#
#             Sensitivity : 0.07538
#             Specificity : 0.95029
#          Pos Pred Value : 0.44776
#          Neg Pred Value : 0.65778
#              Prevalence : 0.34841
#          Detection Rate : 0.02626
#    Detection Prevalence : 0.05865
#       Balanced Accuracy : 0.51283
#
#        'Positive' Class : 0

# %%
# Error rate of the Random Forest
plot(rf1)
# Out:
# Plot with title “rf1”

# %% [markdown]
# The above plot shows that the error rate stablises after ~100 trees and any number of trees beyond doesn't bring any betterment to the error. In view of the same, we shall tune the paramaters of our forest to reduce the number of trees from 500 (default) to 100. Let us observe the change in results. This step helps ascertain an optimal value for *ntree*.

# %%
# Tuning mtry

t <- tuneRF(train_sample[,-5], train_sample[,5],
            stepFactor =2,
            plot = TRUE,
            ntreeTry = 100,
            trace = TRUE,
            improve = 0.005)
# Out:
# Warning message in randomForest.default(x, y, mtry = mtryStart, ntree = ntreeTry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# mtry = 1  OOB error = 0.2188429
# Searching left ...
# Searching right ...
# Warning message in randomForest.default(x, y, mtry = mtryCur, ntree = ntreeTry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# mtry = 2 	OOB error = 0.2327512
# -0.06355357 0.005
# plot without title

# %% [markdown]
# #### Exercise
# - Do any new values of *mtry* emerge on changing *stepfactor* parameter?

# %%
# Tuning with stepfactor=5

t1 <- tuneRF(train_sample[,-5], train_sample[,5],
            stepFactor =5,
            plot = TRUE,
            ntreeTry = 100,
            trace = TRUE,
            improve = 0.005)
# Out:
# Warning message in randomForest.default(x, y, mtry = mtryStart, ntree = ntreeTry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# mtry = 1  OOB error = 0.2180854
# Searching left ...
# Searching right ...
# Warning message in randomForest.default(x, y, mtry = mtryCur, ntree = ntreeTry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# mtry = 4 	OOB error = 0.2452999
# -0.124788 0.005
# plot without title

# %%
# Tuning with stepfactor=4

t1 <- tuneRF(train_sample[,-5], train_sample[,5],
            stepFactor =4,
            plot = TRUE,
            ntreeTry = 100,
            trace = TRUE,
            improve = 0.005)
# Out:
# Warning message in randomForest.default(x, y, mtry = mtryStart, ntree = ntreeTry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# mtry = 1  OOB error = 0.2182064
# Searching left ...
# Searching right ...
# Warning message in randomForest.default(x, y, mtry = mtryCur, ntree = ntreeTry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# mtry = 4 	OOB error = 0.2460457
# -0.1275822 0.005
# plot without title

# %% [markdown]
# Thus, we see that with stepfactor=5,4 no new values of mtry emerge. To further explore, we can try with other examples too.

# %% [markdown]
# We observe that OOB error stablises on assuming the random sample size of 1. This is the optimal value for *mtry* parameter. With the modified values of *mtry* and *ntee*, let us attempt our new Random Forest model. It will hopefully be an improved one.

# %%
rf2 <- randomForest(class~.,
                    data = train_sample,
                    ntree=100,
                    mtry=1,
                    importance= TRUE,
                    proximity = TRUE)
print(rf2)
# Out:
# Warning message in randomForest.default(m, y, ...):
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Call:
#  randomForest(formula = class ~ ., data = train_sample, ntree = 100,      mtry = 1, importance = TRUE, proximity = TRUE)
#                Type of random forest: regression
#                      Number of trees: 100
# No. of variables tried at each split: 1
#
#           Mean of squared residuals: 0.2186588
#                     % Var explained: 2.5

# %%
rf2 <- randomForest(class~.,
                    data = test_sample,
                    ntree=100,
                    mtry=1,
                    importance= TRUE,
                    proximity = TRUE)
print(rf2)
# Out:
# Warning message in randomForest.default(m, y, ...):
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Call:
#  randomForest(formula = class ~ ., data = test_sample, ntree = 100,      mtry = 1, importance = TRUE, proximity = TRUE)
#                Type of random forest: regression
#                      Number of trees: 100
# No. of variables tried at each split: 1
#
#           Mean of squared residuals: 0.2259723
#                     % Var explained: 0.46

# %%
p3<- predict(rf2,test_sample)
head(ifelse(p3>0.5, "Non-Enhancer", "Enhancer"))
p3 <- ifelse(p3>0.5, "1", "0")
confusionMatrix(as.factor(p3),as.factor(test_sample$class))
# Out:
#              3              6              8              9             18
# "Non-Enhancer" "Non-Enhancer"     "Enhancer"     "Enhancer" "Non-Enhancer"
#             20
# "Non-Enhancer"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction    0    1
#          0  466   57
#          1  728 2176
#
#                Accuracy : 0.7709
#                  95% CI : (0.7565, 0.7849)
#     No Information Rate : 0.6516
#     P-Value [Acc > NIR] : < 2.2e-16
#
#                   Kappa : 0.4196
#
#  Mcnemar's Test P-Value : < 2.2e-16
#
#             Sensitivity : 0.3903
#             Specificity : 0.9745
#          Pos Pred Value : 0.8910
#          Neg Pred Value : 0.7493
#              Prevalence : 0.3484
#          Detection Rate : 0.1360
#    Detection Prevalence : 0.1526
#       Balanced Accuracy : 0.6824
#
#        'Positive' Class : 0

# %%
# Number of nodes for the trees
library(ggplot2)
ts <- as.data.frame(treesize(rf2), row.names = c())
ggplot(data = ts, aes(x = `treesize(rf2)`)) + 
  geom_histogram(binwidth = 5, color="purple", fill="lavender", position="identity", alpha=0.7)+
  labs(x="Trees", y="Sizes")+
  ggtitle("Number of Nodes in the Trees")+
  geom_density(alpha=0.6)+
  theme_light()+
  theme(plot.title= element_text(size = 20, face = "bold"),
        axis.title = element_text(size = 12))
# Out:
# plot without title

# %%
# Variable Importance

varImpPlot(rf2)
# Out:
# plot without title

# %%
varImpPlot(rf2, sort = TRUE, n.var = 2, main = "Top 2 variables")
# Out:
# plot without title

# %%
importance(rf2)
# Out:
#               %IncMSE   IncNodePurity
# reads_h3k27ac 13.876614 70.50837
# reads_h3k4me1 12.806248 57.99973
# reads_h3k4me2 12.949535 60.10583
# reads_h3k4me3  9.362545 46.43998

# %%
varUsed(rf2)
# Out:
# [1] 9781 9189 9360 8440

# %%
# Partial Dependence Plots

partialPlot(rf2, train_sample, reads_h3k27ac , "Enhancer")
# Out:
# Plot with title “Partial Dependence on reads_h3k27ac”

# %%
partialPlot(rf2, train_sample, reads_h3k4me2, "Non-Enhancer")
# Out:
# Plot with title “Partial Dependence on reads_h3k4me2”

# %% [markdown]
# The partial dependence plot represents a variable's contribution to the probability of class depiction (classification).

# %% [markdown]
# #### Exercise
# - Try the partial dependence plots for "reads_h3k4me3" variable.

# %%
partialPlot(rf2, train_sample, reads_h3k4me3, "Non-Enhancer")
# Out:
# Plot with title “Partial Dependence on reads_h3k4me3”

# %% [markdown]
# The variable contribution of H3K4me3 is pretty sluggish and imprecise.

# %%
partialPlot(rf2, train_sample, reads_h3k4me2, "Enhancer")
# Out:
# Plot with title “Partial Dependence on reads_h3k4me2”

# %%
# Extract Single tree
getTree(rf2, k=1)
# Out:
#     left daughter right daughter split var split point status prediction
# 1    2             3             1          0.03618215 -3     0.6545083
# 2    0             0             0          0.00000000 -1     0.8155340
# 3    4             5             2          0.50242515 -3     0.6260302
# 4    6             7             3          0.29784278 -3     0.5724551
# 5    8             9             4          2.50465408 -3     0.6980676
# 6   10            11             4          0.27829490 -3     0.5434028
# 7   12            13             2          0.39077512 -3     0.6370656
# 8   14            15             2          2.73542582 -3     0.6851064
# 9   16            17             4         19.12283515 -3     0.9253731
# 10  18            19             1          0.90455373 -3     0.5221328
# 11  20            21             1          1.12164663 -3     0.6772152
# 12  22            23             1          1.12164663 -3     0.6590909
# 13  24            25             1          0.39800364 -3     0.5655738
# 14  26            27             4          0.03975641 -3     0.6749540
# 15  28            29             2          3.07037592 -3     0.8089888
# 16  30            31             4         17.65184783 -3     0.8780488
# 17  32            33             4         47.66794044 -3     1.0000000
# 18  34            35             3          0.12764691 -3     0.5254065
# 19  36            37             2          0.39077512 -3     0.2000000
# 20  38            39             3          0.21274485 -3     0.6709677
# 21   0             0             0          0.00000000 -1     1.0000000
# 22  40            41             3          0.63823454 -3     0.6426667
# 23  42            43             2          0.27912508 -3     0.9523810
# 24  44            45             4          0.35780773 -3     0.2400000
# 25  46            47             4          0.35780773 -3     0.6494845
# 26  48            49             3          0.12764691 -3     0.7692308
# 27  50            51             3          2.08489949 -3     0.6676587
# 28  52            53             3          1.10627320 -3     0.9583333
# 29  54            55             4          1.63001298 -3     0.7538462
# 30  56            57             2          4.07522622 -3     0.9000000
# ⋮   ⋮             ⋮              ⋮         ⋮           ⋮      ⋮
# 696 716           717            3         1.2764691   -3     0.8571429
# 697 718           719            3         0.7233325   -3     1.0000000
# 698   0             0            0         0.0000000   -1     0.0000000
# 699   0             0            0         0.0000000   -1     0.0000000
# 700 720           721            4         0.3578077   -3     0.5000000
# 701   0             0            0         0.0000000   -1     1.0000000
# 702   0             0            0         0.0000000   -1     1.0000000
# 703 722           723            4         0.5963462   -3     1.0000000
# 704   0             0            0         0.0000000   -1     1.0000000
# 705   0             0            0         0.0000000   -1     1.0000000
# 706   0             0            0         0.0000000   -1     1.0000000
# 707   0             0            0         0.0000000   -1     1.0000000
# 708   0             0            0         0.0000000   -1     1.0000000
# 709   0             0            0         0.0000000   -1     1.0000000
# 710   0             0            0         0.0000000   -1     0.8000000
# 711   0             0            0         0.0000000   -1     0.9230769
# 712   0             0            0         0.0000000   -1     1.0000000
# 713   0             0            0         0.0000000   -1     0.0000000
# 714   0             0            0         0.0000000   -1     1.0000000
# 715   0             0            0         0.0000000   -1     1.0000000
# 716 724           725            4         0.2385385   -3     1.0000000
# 717   0             0            0         0.0000000   -1     0.0000000
# 718   0             0            0         0.0000000   -1     1.0000000
# 719   0             0            0         0.0000000   -1     1.0000000
# 720   0             0            0         0.0000000   -1     1.0000000
# 721   0             0            0         0.0000000   -1     0.0000000
# 722   0             0            0         0.0000000   -1     1.0000000
# 723   0             0            0         0.0000000   -1     1.0000000
# 724   0             0            0         0.0000000   -1     1.0000000
# 725   0             0            0         0.0000000   -1     1.0000000

# %% [markdown]
# #### Exercise
# - The above example elaborates the definition for the first tree. Try different values of *k* for visualizing other trees in the forest.

# %%
## Fifth tree
getTree(rf2, k=5)
# Out:
#     left daughter right daughter split var split point status prediction
# 1    2             3             4          0.27829490 -3     0.6483805
# 2    4             5             1          0.03618215 -3     0.6294678
# 3    6             7             2          1.39562542 -3     0.7007701
# 4    8             9             4          0.03975641 -3     0.8087649
# 5   10            11             4          0.11926924 -3     0.5848214
# 6   12            13             4          0.51683338 -3     0.6631737
# 7   14            15             3          4.51019073 -3     0.8049793
# 8   16            17             2          0.05582502 -3     0.8228942
# 9   18            19             2          0.39077512 -3     0.6410256
# 10  20            21             4          0.03975641 -3     0.5259179
# 11  22            23             1          0.18091075 -3     0.6348624
# 12  24            25             3          1.48921392 -3     0.6420455
# 13  26            27             2          0.05582502 -3     0.7428571
# 14  28            29             2          7.98297739 -3     0.8418367
# 15  30            31             3         10.33939951 -3     0.6444444
# 16   0             0             0          0.00000000 -1     0.8461538
# 17   0             0             0          0.00000000 -1     0.3333333
# 18  32            33             3          0.04254897 -3     0.6666667
# 19   0             0             0          0.00000000 -1     0.3333333
# 20   0             0             0          0.00000000 -1     0.4903047
# 21  34            35             3          0.12764691 -3     0.5486726
# 22  36            37             1          0.10854645 -3     0.4913793
# 23  38            39             3          0.46803866 -3     0.6519507
# 24  40            41             1          2.49656830 -3     0.6486486
# 25  42            43             3          1.70195877 -3     0.3000000
# 26   0             0             0          0.00000000 -1     0.0000000
# 27  44            45             4          2.14684636 -3     0.7482014
# 28  46            47             2          3.29367599 -3     0.8541667
# 29   0             0             0          0.00000000 -1     0.2500000
# 30  48            49             1          1.66437887 -3     0.4827586
# ⋮   ⋮             ⋮              ⋮         ⋮           ⋮      ⋮
# 668   0             0            0         0.0000000   -1     1.0000000
# 669   0             0            0         0.0000000   -1     0.0000000
# 670   0             0            0         0.0000000   -1     1.0000000
# 671   0             0            0         0.0000000   -1     1.0000000
# 672   0             0            0         0.0000000   -1     0.0000000
# 673   0             0            0         0.0000000   -1     0.2500000
# 674   0             0            0         0.0000000   -1     0.7500000
# 675   0             0            0         0.0000000   -1     0.6666667
# 676   0             0            0         0.0000000   -1     0.7142857
# 677   0             0            0         0.0000000   -1     1.0000000
# 678   0             0            0         0.0000000   -1     1.0000000
# 679   0             0            0         0.0000000   -1     0.3333333
# 680   0             0            0         0.0000000   -1     0.0000000
# 681 690           691            2         0.6140752   -3     0.6363636
# 682   0             0            0         0.0000000   -1     1.0000000
# 683   0             0            0         0.0000000   -1     1.0000000
# 684   0             0            0         0.0000000   -1     0.6666667
# 685   0             0            0         0.0000000   -1     1.0000000
# 686   0             0            0         0.0000000   -1     0.6363636
# 687 692           693            3         0.4680387   -3     0.7857143
# 688   0             0            0         0.0000000   -1     1.0000000
# 689   0             0            0         0.0000000   -1     1.0000000
# 690   0             0            0         0.0000000   -1     1.0000000
# 691 694           695            2         1.0606753   -3     0.5000000
# 692 696           697            1         0.3256393   -3     0.8461538
# 693   0             0            0         0.0000000   -1     0.0000000
# 694   0             0            0         0.0000000   -1     0.0000000
# 695   0             0            0         0.0000000   -1     0.8000000
# 696   0             0            0         0.0000000   -1     1.0000000
# 697   0             0            0         0.0000000   -1     0.8000000

# %%
# Multidimensional Scaling (MDS) plot of proximity matrix.

MDSplot(rf2, train_sample$class)
# Out:
# Warning message in RColorBrewer::brewer.pal(nlevs, "Set1"):
# “minimal value for n is 3, returning requested palette with 3 different levels
# ”
# plot without title

# %% [markdown]
# # Notes
#
#   1.  The authors [@Rajagopal2013] construed p300 (a transcription co-activator) binding sites overlapping DNase-I hypersentitive sites and distal to annotated transcription start sites (TSS) as active p300 binding sites representative of enhancers.
#   2. Clusters with presence or absence of H3K36me3 were hypothesized to represent genic and inter-genic enhancers respectively.
#   3. While pre-processing the genomic ranges data if you need to convert WIG file to BED file, you may want to refer to BEDOPS -> wig2bed() function. This is available as a command line utility.
#
# P.S. During intermediary partitioning, if the node has the lowest Gini Index, it becomes leaf node. That will most likely be the case when all remaining non-root nodes have been exhausted, checking for impurity score.
#
# All workshop study material is available at my github page (https://github.com/shauryajauhari).

# %% [markdown]
# The excercises are embedded in the body of the text itself. Please look for the same.
