# %% [markdown]
# # Decision Trees and Random Forests: Application for Enhancer Prediction

# %% [markdown]
# Shaurya Jauhari (Email: shauryajauhari@gzhmu.edu.cn)

# %% [markdown]
# Welcome to the second workshop in the series of **Machine Learning Fundamentals**. In this session, we shall explore the theory of **Decision Trees** and scale it to the broader concept of **Random Forests**. Decision trees epitomize the divide and conquer strategy to accomplish classification tasks (although they could also be implemented for regression chores as well)(Quinlan 1986, Rokach 2005). From the previous session on **Logistic Regression**, you may recall that if the response variable is catergorical in nature (factors in R), we aim classification, or else, if the response variable is continuous, it denotes regression. Classification and regression methodologies are both categorized under supervised machine learning. The theme of machine learning was realized in 1950s and since then, coupled with the data deluge and upheaval in computational prowess, has exhibited stronghold in data analysis domain (See figure below).

# %% [markdown]
# ![Machine Learning Genesis](./ML_Genesis.png)

# %% [markdown]
# In order to appreciate the concept of random forests, it is incumbent to learn about decision trees. A decision tree is the unit of random forest.

# %% [markdown]
# There is also an added understanding about dimensionality reduction in decision trees (and random forests as well). Recollecting the same concept in logistic regression, the idea was to penalize "non-performing" features by reducing their coefficients close to(alpha=0:Ridge) or equal to zero(alpha=1:Lasso)(there is also a provision for replicating the objective of train-test data partitioning, i.e. cross-validation). In decision trees, entropy, information gain, variance-bias, chi-square coefficients, gini-index, etc. parameters are optionally calculated to ascertain the best attribute to split/ partition the tree. It is crucial to engender the tree a definitive structure, else the curse of biasness in decision trees for continuous and nominal data comes to play.

# %% [markdown]
# Random forests enlighten on the dogma of democracy, i.e. *majority wins*. Decision Trees are rudimentary classification algorithms that, at a low-level, are synonymous to *if-then* conditional statements in programming languages. They follow the strategy of iterative recursion, and intuitively the leaf nodes hold the final verdict. The highest aggregate from all leaf nodes (terminals) is graded as the output of that decision tree.
#
# In this module, we shall delve into creation of basic decision trees to have an understanding of it. For the purpose, we shall load the package **party** and make use of the function **ctree()** to calculate and analyze decision trees. Furthermore, we shall require the packages **rpart**, **party**, **randomForest** as well. Let's load them up.

# %% [markdown]
# # Decision Trees

# %% [markdown]
# ## Package Installation and Loading

# %%
install.packages("party", dependencies = TRUE, repos = "https://mirrors.tuna.tsinghua.edu.cn/CRAN/")
install.packages("rpart", dependencies = TRUE, repos = "https://mirrors.tuna.tsinghua.edu.cn/CRAN/")
install.packages("rpart.plot", dependencies = TRUE, repos = "https://mirrors.tuna.tsinghua.edu.cn/CRAN/")
library(party)
library(rpart)
library(rpart.plot)
# Out:
# Installing package into ‘/Users/mei/Library/R/3.6/library’
# (as ‘lib’ is unspecified)
# The downloaded binary packages are in
# 	/var/folders/hm/c3_fjypn62v5xh5b5ygv267m0000gn/T//RtmpraR9Z0/downloaded_packages
# Installing package into ‘/Users/mei/Library/R/3.6/library’
# (as ‘lib’ is unspecified)
# The downloaded binary packages are in
# 	/var/folders/hm/c3_fjypn62v5xh5b5ygv267m0000gn/T//RtmpraR9Z0/downloaded_packages
# Installing package into ‘/Users/mei/Library/R/3.6/library’
# (as ‘lib’ is unspecified)
# The downloaded binary packages are in
# 	/var/folders/hm/c3_fjypn62v5xh5b5ygv267m0000gn/T//RtmpraR9Z0/downloaded_packages
# Loading required package: grid
#
# Loading required package: mvtnorm
#
# Loading required package: modeltools
#
# Loading required package: stats4
#
# Loading required package: strucchange
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Loading required package: sandwich

# %% [markdown]
# Let us now, pick up a dataset. The dataset pertains to the soft computation of the **enhancer prediction** module in bioinformatics. We certainly take into cognizance the biological implications about enhancer regions (See figure below).
# Certain known classes of proteins/ cis-regulatory elements called Transcription Factors (TFs) and Transcription Co-Activators (TCoAs) are programmed to bind to regions in the genome called *Enhancers*, that remotely orchestrate the phenomena of gene regulation. They are at a distal location to the *Promoters*, regions associated with genes and respective Transcription Start Sites (TSS). On stimulus from TFs, the enhancer and promoter sequences reciprocate and actuate the transcription machinery.

# %% [markdown]
# ![Enhancer Prediction Basis](./WorkFlow_Illustration.jpg)

# %% [markdown]
# ## Dataset handling

# %% [markdown]
# For use in this session, we have chosen a compound dataset from the [here](https://nbviewer.jupyter.org/github/shauryajauhari/Machine_Learning/blob/master/Machine_Learning_Deep_Learning/enhancer_prediction_dataset_protocol.ipynb).

# %%
epdata <- readRDS("../Machine_Learning_Deep_Learning/data/ep_data.rds")
rownames(epdata) <- c()

epdata$class <- as.numeric(as.factor(epdata$class))-1

# %%
# Let's look at the data.

head(epdata)
# Out:
#   reads_h3k27ac reads_h3k4me3 reads_h3k4me2 reads_h3k4me1 class
# 1 0             0             0             0.0000000     1
# 2 0             0             0             0.0000000     1
# 3 0             0             0             0.0000000     1
# 4 0             0             0             0.0568576     1
# 5 0             0             0             0.0568576     0
# 6 0             0             0             0.0568576     0

# %% [markdown]
# ### Deploying Tree Models
# #### 'party' package

# %% [markdown]
# Let us now partition the data into test and validation cases. We shall be assuming 80% of the data for training and 20% for testing tasks.

# %%
set.seed(3)
data_partition <- sample(2, nrow(epdata), replace = TRUE, prob = c(0.8,0.2))
train <- epdata[data_partition==1,]
test <- epdata[data_partition==2,]

# %% [markdown]
# #### Exercise
# - Try data partitioning with a 70:30 split for training and testing examples. See if it makes any difference in the classification ahead.

# %%
data_partition1 <- sample(2, nrow(epdata), replace = TRUE, prob = c(0.7,0.3))

# %%
cat("We have",nrow(train),"training examples and",nrow(test),"for testing.")
# Out:
# We have 5932145 training examples and 1485134 for testing.

# %%
ep_tree <- ctree(class ~ reads_h3k27ac + reads_h3k4me3 + reads_h3k4me2 + reads_h3k4me1, data= train)
print(ep_tree)
# Out:
# 	 Conditional inference tree with 35 terminal nodes
#
# Response:  class
# Inputs:  reads_h3k27ac, reads_h3k4me3, reads_h3k4me2, reads_h3k4me1
# Number of observations:  5932145
#
# 1) reads_h3k4me1 <= 0; criterion = 1, statistic = 857.757
#   2) reads_h3k27ac <= 0; criterion = 1, statistic = 2837.024
#     3) reads_h3k4me2 <= 0; criterion = 1, statistic = 650.791
#       4) reads_h3k4me3 <= 0; criterion = 1, statistic = 551.509
#         5)*  weights = 171999
#       4) reads_h3k4me3 > 0
#         6)*  weights = 16158
#     3) reads_h3k4me2 > 0
#       7)*  weights = 26343
#   2) reads_h3k27ac > 0
#     8) reads_h3k4me2 <= 0.216698; criterion = 0.999, statistic = 13.686
#       9) reads_h3k4me3 <= 0.0809982; criterion = 1, statistic = 18.729
#         10) reads_h3k4me3 <= 0; criterion = 0.972, statistic = 7.246
#           11)*  weights = 97366
#         10) reads_h3k4me3 > 0
#           12)*  weights = 169730
#       9) reads_h3k4me3 > 0.0809982
#         13)*  weights = 84702
#     8) reads_h3k4me2 > 0.216698
#       14)*  weights = 23908
# 1) reads_h3k4me1 > 0
#   15) reads_h3k4me3 <= 7.12784; criterion = 1, statistic = 768.589
#     16) reads_h3k4me1 <= 1.42144; criterion = 1, statistic = 305.554
#       17) reads_h3k4me3 <= 0.0809982; criterion = 1, statistic = 23.767
#         18) reads_h3k4me3 <= 0; criterion = 1, statistic = 30.175
#           19)*  weights = 524035
#         18) reads_h3k4me3 > 0
#           20) reads_h3k4me2 <= 0.130019; criterion = 0.98, statistic = 7.905
#             21) reads_h3k27ac <= 0.0734144; criterion = 0.998, statistic = 11.795
#               22)*  weights = 204411
#             21) reads_h3k27ac > 0.0734144
#               23)*  weights = 917482
#           20) reads_h3k4me2 > 0.130019
#             24)*  weights = 841139
#       17) reads_h3k4me3 > 0.0809982
#         25) reads_h3k4me3 <= 2.34895; criterion = 1, statistic = 72.054
#           26) reads_h3k4me2 <= 0.693432; criterion = 0.99, statistic = 9.101
#             27) reads_h3k4me3 <= 0.161996; criterion = 1, statistic = 32.259
#               28) reads_h3k4me2 <= 0.086679; criterion = 0.997, statistic = 11.669
#                 29) reads_h3k4me1 <= 0.284288; criterion = 0.96, statistic = 6.591
#                   30)*  weights = 329058
#                 29) reads_h3k4me1 > 0.284288
#                   31) reads_h3k27ac <= 0.25695; criterion = 0.952, statistic = 6.278
#                     32)*  weights = 28288
#                   31) reads_h3k27ac > 0.25695
#                     33)*  weights = 29103
#               28) reads_h3k4me2 > 0.086679
#                 34) reads_h3k27ac <= 0.513901; criterion = 0.986, statistic = 8.531
#                   35)*  weights = 845705
#                 34) reads_h3k27ac > 0.513901
#                   36)*  weights = 182751
#             27) reads_h3k4me3 > 0.161996
#               37) reads_h3k4me1 <= 0.739148; criterion = 0.997, statistic = 11.348
#                 38)*  weights = 676533
#               37) reads_h3k4me1 > 0.739148
#                 39) reads_h3k4me2 <= 0.173358; criterion = 0.965, statistic = 6.853
#                   40)*  weights = 6353
#                 39) reads_h3k4me2 > 0.173358
#                   41)*  weights = 105253
#           26) reads_h3k4me2 > 0.693432
#             42) reads_h3k27ac <= 3.63401; criterion = 1, statistic = 17.759
#               43)*  weights = 231703
#             42) reads_h3k27ac > 3.63401
#               44)*  weights = 5989
#         25) reads_h3k4me3 > 2.34895
#           45) reads_h3k27ac <= 0.477193; criterion = 1, statistic = 15.353
#             46)*  weights = 11548
#           45) reads_h3k27ac > 0.477193
#             47) reads_h3k27ac <= 1.61512; criterion = 0.953, statistic = 6.3
#               48)*  weights = 17477
#             47) reads_h3k27ac > 1.61512
#               49)*  weights = 4607
#     16) reads_h3k4me1 > 1.42144
#       50) reads_h3k4me2 <= 0.606753; criterion = 1, statistic = 40.254
#         51)*  weights = 70022
#       50) reads_h3k4me2 > 0.606753
#         52) reads_h3k4me1 <= 1.8763; criterion = 1, statistic = 32.104
#           53)*  weights = 71573
#         52) reads_h3k4me1 > 1.8763
#           54) reads_h3k4me2 <= 4.76735; criterion = 1, statistic = 21.853
#             55) reads_h3k4me1 <= 2.84288; criterion = 0.965, statistic = 6.86
#               56)*  weights = 68358
#             55) reads_h3k4me1 > 2.84288
#               57)*  weights = 55525
#           54) reads_h3k4me2 > 4.76735
#             58)*  weights = 18653
#   15) reads_h3k4me3 > 7.12784
#     59) reads_h3k4me1 <= 1.64887; criterion = 1, statistic = 102.36
#       60) reads_h3k4me1 <= 0.625433; criterion = 1, statistic = 31.342
#         61)*  weights = 27818
#       60) reads_h3k4me1 > 0.625433
#         62) reads_h3k4me3 <= 20.209; criterion = 1, statistic = 25.361
#           63) reads_h3k27ac <= 1.24804; criterion = 0.967, statistic = 6.981
#             64) reads_h3k4me3 <= 10.7728; criterion = 0.995, statistic = 10.309
#               65)*  weights = 7581
#             64) reads_h3k4me3 > 10.7728
#               66)*  weights = 7487
#           63) reads_h3k27ac > 1.24804
#             67)*  weights = 19492
#         62) reads_h3k4me3 > 20.209
#           68)*  weights = 14028
#     59) reads_h3k4me1 > 1.64887
#       69)*  weights = 19967

# %%
plot(ep_tree)
# Out:
# plot without title

# %% [markdown]
# It is a pretty dense tree to make sense of; especially from the visualization. The summary says that it has 69 overall nodes.

# %% [markdown]
# #### Exercise
# - Addtionally, the function ctree() offers flexibility in terms of defining parameters for classification via ctree_control() function. Look for attributes *mincriterion* and *minsplit*. The former denotes the confidence level (i.e. 1- probability value), while the latter signifies the minimum number of samples required for splitting a tree branch into two. The default values are 0.95 and 20 respectively. See if any alteration makes a difference.
# - They can be accessed via *controls*, i.e. ctree(formula,data,controls=ctree_control(mincriterion= , minsplit= ).
# - You may explore other attributes too.

# %%
tree_pred <- predict(ep_tree,test)
head(ifelse(tree_pred>0.5, "Non-Enhancer", "Enhancer"))
tree_pred <- ifelse(tree_pred>0.5, "1", "0")
# Out:
#      class
# [1,] Enhancer
# [2,] Enhancer
# [3,] Enhancer
# [4,] Enhancer
# [5,] Enhancer
# [6,] Enhancer

# %%
tree_pred_prob <- predict(ep_tree,test, type="prob")
head(tree_pred_prob)
# Out:
# [[1]]
# [1] 0.2153559
#
# [[2]]
# [1] 0.2153559
#
# [[3]]
# [1] 0.1199805
#
# [[4]]
# [1] 0.2153559
#
# [[5]]
# [1] 0.2153559
#
# [[6]]
# [1] 0.1199805

# %% [markdown]
# #### Misclassification Error

# %%
tab <- table(tree_pred, test$class)
print(tab)
# Out:
#
# tree_pred       0       1
#         0 1308037  177097

# %%
accur <- 1 - sum(diag(tab))/sum(tab)
cat("The accuracy of the model is",accur*100,"%")
#print("\n")
ifelse(accur>90, print("Not bad."), print("Poor."))
# Out:
# The accuracy of the model is 11.92465 %[1] "Poor."
# [1] "Poor."

# %% [markdown]
# #### Exercise
# - What do you think the misclassification error will be like if the table is drawn for *train* data?

# %%
tree_pred1 <- predict(ep_tree,train)
head(ifelse(tree_pred1>0.5, "Non-Enhancer", "Enhancer"))
tree_pred1 <- ifelse(tree_pred1 > 0.5, "1", "0")

# training data

tab1 <- table(tree_pred1, train$class)
print(tab1)

accur <- 1 - sum(diag(tab1))/sum(tab1)
cat("The accuracy of the model is",accur*100,"%")

ifelse(accur>90, print("Not bad."), print("Poor."))
# Out:
#      class
# [1,] Enhancer
# [2,] Enhancer
# [3,] Enhancer
# [4,] Enhancer
# [5,] Enhancer
# [6,] Enhancer
#
# tree_pred1       0       1
#          0 5224024  708121
# The accuracy of the model is 11.93701 %[1] "Poor."
# [1] "Poor."

# %% [markdown]
# #### 'rpart' package

# %%
ep_tree1 <- rpart(class ~ reads_h3k27ac + reads_h3k4me3 + reads_h3k4me2 + reads_h3k4me1, data= train)
print(ep_tree1)
# Out:
# n= 5932145
#
# node), split, n, deviance, yval
#       * denotes terminal node
#
# 1) root 5932145 623592.5 0.1193701 *

# %%
rpart.plot(ep_tree1)
# Out:
# plot without title

# %%
tree_pred2 <- predict(ep_tree1,test)
head(tree_pred2)
# Out:
# [1] 0.1193701 0.1193701 0.1193701 0.1193701 0.1193701 0.1193701

# %% [markdown]
# An important point to consider is that the enhancers outnumber non-enhancers by a near-10 fold margin in the current dataset (as depicted below). This engenders a natural bias.

# %%
table(epdata$class)
# Out:
#       0       1
# 6532061  885218

# %% [markdown]
# There is a complete contrast between the two trees drawn from *ctree()* and *rpart()* functions. The *ctree* uses a significance test procedure in order to select variables instead of selecting the variable that maximizes an information measure (e.g. Gini coefficient). Basically the methodology of both approaches is different; *rpart* is a CART algorithm, while *party* is a CHAID algorithm. (http://www.bzst.com/2006/10/classification-trees-cart-vs-chaid.html).

# %% [markdown]
# Next, we move to the more fuller concept, of Random Forests.

# %% [markdown]
# # Random Forests

# %% [markdown]
# Decision trees are accomodated inside Random Forests. This ensemble brings about variety in data classification and hence more robustness. This notion also helps in avoidance of overfitting. Random forests can deal with large number of features and selects them for constructing trees on the basis of importance. As we will see, they are easy to implement and have two free parameters to tune- (i) *ntree* signifying the number of trees (where default value is 500), and (ii) *mtry* denoting variables randomly selected for each split (default here sq(p) when classification is sought, and (p/3) when regression; p is the total number of features in the dataset)

# %% [markdown]
# ## Package Installation and Loading (randomForest)

# %%
install.packages("randomForest", dependencies = TRUE, repos = "https://mirrors.tuna.tsinghua.edu.cn/CRAN/")
install.packages("caret", dependencies = TRUE, repos = "https://mirrors.tuna.tsinghua.edu.cn/CRAN/")
library(randomForest)
library(caret)
# Out:
# Installing package into ‘/Users/mei/Library/R/3.6/library’
# (as ‘lib’ is unspecified)
# The downloaded binary packages are in
# 	/var/folders/hm/c3_fjypn62v5xh5b5ygv267m0000gn/T//RtmpraR9Z0/downloaded_packages
# Installing package into ‘/Users/mei/Library/R/3.6/library’
# (as ‘lib’ is unspecified)
# The downloaded binary packages are in
# 	/var/folders/hm/c3_fjypn62v5xh5b5ygv267m0000gn/T//RtmpraR9Z0/downloaded_packages

# %% [markdown]
# There are basically three steps involved in construction of a Random Forest:
#     1. Draw *ntree* bootstrap samples.
#     2. For each bootstrap sample, grow a un-pruned tree by choosing best split based on a random sample of *mtry* predictors at each node.
#     3. Predict new daat using majority votes for classification, and average for regression based on *ntree* trees.

# %% [markdown]
# For application, we shall consider a subset of the data we used for decision trees. The random forests algorithm tend to consume greater in terms of computational resources.

# %%
epdata_sample <- readRDS("../Machine_Learning_Deep_Learning/data/ep_data_sample.rds")
rownames(epdata_sample) <- c()
epdata_sample$class <- as.numeric(as.factor(epdata_sample$class))-1

## Data partitioning

set.seed(5)
data_partition <- sample(2, nrow(epdata_sample), replace = TRUE, prob = c(0.7,0.3))
train_sample <- epdata_sample[data_partition==1,]
test_sample <- epdata_sample[data_partition==2,]

# %%
# Execute random forest algorithm
rf1 <- randomForest(formula= class ~ reads_h3k27ac + reads_h3k4me3 + reads_h3k4me2 + reads_h3k4me1, 
                    data= train_sample,
                   proximity = TRUE,
                   ntree=500)
print(rf1)
# Out:
# Warning message in randomForest.default(m, y, ...):
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Call:
#  randomForest(formula = class ~ reads_h3k27ac + reads_h3k4me3 +      reads_h3k4me2 + reads_h3k4me1, data = train_sample, proximity = TRUE,      ntree = 500)
#                Type of random forest: regression
#                      Number of trees: 500
# No. of variables tried at each split: 1
#
#           Mean of squared residuals: 0.1093793
#                     % Var explained: -2.41

# %%
# Prediction and Confusion Matrix
p1<- predict(rf1,train_sample)
head(ifelse(p1>0.5, "Non-Enhancer", "Enhancer"))
p1 <- ifelse(p1>0.5, "1", "0")
confusionMatrix(as.factor(p1),as.factor(train_sample$class))
# Out:
#          1          2          4          5          7         10
# "Enhancer" "Enhancer" "Enhancer" "Enhancer" "Enhancer" "Enhancer"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction    0    1
#          0 6112  799
#          1    0   47
#
#                Accuracy : 0.8852
#                  95% CI : (0.8774, 0.8926)
#     No Information Rate : 0.8784
#     P-Value [Acc > NIR] : 0.04318
#
#                   Kappa : 0.0937
#
#  Mcnemar's Test P-Value : < 2e-16
#
#             Sensitivity : 1.00000
#             Specificity : 0.05556
#          Pos Pred Value : 0.88439
#          Neg Pred Value : 1.00000
#              Prevalence : 0.87841
#          Detection Rate : 0.87841
#    Detection Prevalence : 0.99325
#       Balanced Accuracy : 0.52778
#
#        'Positive' Class : 0

# %%
p2<- predict(rf1,test_sample)
head(ifelse(p2>0.5, "Non-Enhancer", "Enhancer"))
p2 <- ifelse(p2>0.5, "1", "0")
confusionMatrix(as.factor(p2),as.factor(test_sample$class))
# Out:
#          3          6          8          9         18         20
# "Enhancer" "Enhancer" "Enhancer" "Enhancer" "Enhancer" "Enhancer"
# Warning message in confusionMatrix.default(as.factor(p2), as.factor(test_sample$class)):
# “Levels are not in the same order for reference and data. Refactoring data to match.”
# Confusion Matrix and Statistics
#
#           Reference
# Prediction    0    1
#          0 2666  376
#          1    0    0
#
#                Accuracy : 0.8764
#                  95% CI : (0.8642, 0.8879)
#     No Information Rate : 0.8764
#     P-Value [Acc > NIR] : 0.5137
#
#                   Kappa : 0
#
#  Mcnemar's Test P-Value : <2e-16
#
#             Sensitivity : 1.0000
#             Specificity : 0.0000
#          Pos Pred Value : 0.8764
#          Neg Pred Value :    NaN
#              Prevalence : 0.8764
#          Detection Rate : 0.8764
#    Detection Prevalence : 1.0000
#       Balanced Accuracy : 0.5000
#
#        'Positive' Class : 0

# %%
# Error rate of the Random Forest
plot(rf1)
# Out:
# Plot with title “rf1”

# %% [markdown]
# The above plot shows that the error rate stablises after ~250 trees and any number of trees beyond doesn't bring any betterment to the error. In view of the same, we shall tune the paramaters of our forest to reduce the number of trees from 500 (default) to 250. Let us observe the change in results. This step helps ascertain an optimal value for *ntree*.

# %%
# Tuning mtry

t <- tuneRF(train_sample[,-5], train_sample[,5],
            stepFactor =2,
            plot = TRUE,
            ntreeTry = 250,
            trace = TRUE,
            improve = 0.005)
# Out:
# Warning message in randomForest.default(x, y, mtry = mtryStart, ntree = ntreeTry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# mtry = 1  OOB error = 0.1094004
# Searching left ...
# Searching right ...
# Warning message in randomForest.default(x, y, mtry = mtryCur, ntree = ntreeTry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# mtry = 2 	OOB error = 0.1160057
# -0.06037777 0.005
# plot without title

# %% [markdown]
# #### Exercise
# - Do any new values of *mtry* emerge on changing *stepfactor* parameter?

# %%
# Tuning with stepfactor=5

t1 <- tuneRF(train_sample[,-5], train_sample[,5],
            stepFactor =5,
            plot = TRUE,
            ntreeTry = 250,
            trace = TRUE,
            improve = 0.005)
# Out:
# Warning message in randomForest.default(x, y, mtry = mtryStart, ntree = ntreeTry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# mtry = 1  OOB error = 0.1090662
# Searching left ...
# Searching right ...
# Warning message in randomForest.default(x, y, mtry = mtryCur, ntree = ntreeTry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# mtry = 4 	OOB error = 0.1219695
# -0.1183068 0.005
# plot without title

# %%
# Tuning with stepfactor=4

t1 <- tuneRF(train_sample[,-5], train_sample[,5],
            stepFactor =4,
            plot = TRUE,
            ntreeTry = 250,
            trace = TRUE,
            improve = 0.005)
# Out:
# Warning message in randomForest.default(x, y, mtry = mtryStart, ntree = ntreeTry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# mtry = 1  OOB error = 0.1094836
# Searching left ...
# Searching right ...
# Warning message in randomForest.default(x, y, mtry = mtryCur, ntree = ntreeTry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# mtry = 4 	OOB error = 0.122266
# -0.1167523 0.005
# plot without title

# %% [markdown]
# Thus, we see that with stepfactor=5,4 no new values of mtry emerge. To further explore, we can try with other examples too.

# %% [markdown]
# We observe that OOB error stablises on assuming the random sample size of 1. This is the optimal value for *mtry* parameter. With the modified values of *mtry* and *ntee*, let us attempt our new Random Forest model. It will hopefully be an improved one.

# %%
rf2 <- randomForest(class~.,
                    data = train_sample,
                    ntree=250,
                    mtry=1,
                    importance= TRUE,
                    proximity = TRUE)
print(rf2)
# Out:
# Warning message in randomForest.default(m, y, ...):
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Call:
#  randomForest(formula = class ~ ., data = train_sample, ntree = 250,      mtry = 1, importance = TRUE, proximity = TRUE)
#                Type of random forest: regression
#                      Number of trees: 250
# No. of variables tried at each split: 1
#
#           Mean of squared residuals: 0.1095931
#                     % Var explained: -2.61

# %%
rf2 <- randomForest(class~.,
                    data = test_sample,
                    ntree=250,
                    mtry=1,
                    importance= TRUE,
                    proximity = TRUE)
print(rf2)
# Out:
# Warning message in randomForest.default(m, y, ...):
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Call:
#  randomForest(formula = class ~ ., data = test_sample, ntree = 250,      mtry = 1, importance = TRUE, proximity = TRUE)
#                Type of random forest: regression
#                      Number of trees: 250
# No. of variables tried at each split: 1
#
#           Mean of squared residuals: 0.1118769
#                     % Var explained: -3.28

# %%
p3<- predict(rf2,test_sample)
head(ifelse(p3>0.5, "Non-Enhancer", "Enhancer"))
p3 <- ifelse(p3>0.5, "1", "0")
confusionMatrix(as.factor(p3),as.factor(test_sample$class))
# Out:
#          3          6          8          9         18         20
# "Enhancer" "Enhancer" "Enhancer" "Enhancer" "Enhancer" "Enhancer"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction    0    1
#          0 2666  338
#          1    0   38
#
#                Accuracy : 0.8889
#                  95% CI : (0.8772, 0.8998)
#     No Information Rate : 0.8764
#     P-Value [Acc > NIR] : 0.01833
#
#                   Kappa : 0.1646
#
#  Mcnemar's Test P-Value : < 2e-16
#
#             Sensitivity : 1.0000
#             Specificity : 0.1011
#          Pos Pred Value : 0.8875
#          Neg Pred Value : 1.0000
#              Prevalence : 0.8764
#          Detection Rate : 0.8764
#    Detection Prevalence : 0.9875
#       Balanced Accuracy : 0.5505
#
#        'Positive' Class : 0

# %%
# Number of nodes for the trees
library(ggplot2)
ts <- as.data.frame(treesize(rf2), row.names = c())
ggplot(data = ts, aes(x = `treesize(rf2)`)) + 
  geom_histogram(binwidth = 5, color="purple", fill="lavender", position="identity", alpha=0.7)+
  labs(x="Trees", y="Sizes")+
  ggtitle("Number of Nodes in the Trees")+
  geom_density(alpha=0.6)+
  theme_light()+
  theme(plot.title= element_text(size = 20, face = "bold"),
        axis.title = element_text(size = 12))
# Out:
# plot without title

# %%
# Variable Importance

varImpPlot(rf2)
# Out:
# plot without title

# %%
varImpPlot(rf2, sort = TRUE, n.var = 2, main = "Top 2 variables")
# Out:
# plot without title

# %%
importance(rf2)
# Out:
#               %IncMSE  IncNodePurity
# reads_h3k27ac 15.22538 30.30698
# reads_h3k4me3 13.44919 24.56461
# reads_h3k4me2 19.15000 28.66528
# reads_h3k4me1 16.31767 29.15401

# %%
varUsed(rf2)
# Out:
# [1] 18359 16489 17984 17656

# %%
# Partial Dependence Plots

partialPlot(rf2, train_sample, reads_h3k27ac , "Enhancer")
# Out:
# Plot with title “Partial Dependence on reads_h3k27ac”

# %%
partialPlot(rf2, train_sample, reads_h3k4me2, "Non-Enhancer")
# Out:
# Plot with title “Partial Dependence on reads_h3k4me2”

# %% [markdown]
# The partial dependence plot represents a variable's contribution to the probability of class depiction (classification).

# %% [markdown]
# #### Exercise
# - Try the partial dependence plots for "reads_h3k4me3" variable.

# %%
partialPlot(rf2, train_sample, reads_h3k4me3, "Non-Enhancer")
# Out:
# Plot with title “Partial Dependence on reads_h3k4me3”

# %% [markdown]
# The variable contribution of H3K4me3 is pretty sluggish and imprecise.

# %%
partialPlot(rf2, train_sample, reads_h3k4me2, "Enhancer")
# Out:
# Plot with title “Partial Dependence on reads_h3k4me2”

# %%
# Extract Single tree
getTree(rf2, k=1)
# Out:
#     left daughter right daughter split var split point status prediction
# 1    2             3             2          0.02024955 -3     0.11998685
# 2    4             5             1          0.01835360 -3     0.16243655
# 3    6             7             1          0.64237550 -3     0.11367069
# 4    8             9             3          0.08667925 -3     0.20952381
# 5   10            11             3          0.02166975 -3     0.14532872
# 6   12            13             4          0.76757700 -3     0.10843373
# 7   14            15             2          0.22274450 -3     0.15123457
# 8    0             0             0          0.00000000 -1     0.21568627
# 9    0             0             0          0.00000000 -1     0.00000000
# 10  16            17             4          0.08528630 -3     0.22388060
# 11  18            19             4          1.44987000 -3     0.12162162
# 12  20            21             3          3.03376500 -3     0.11152416
# 13  22            23             3          0.41172550 -3     0.06976744
# 14  24            25             2          0.10124760 -3     0.24615385
# 15  26            27             2         25.87895000 -3     0.08762887
# 16  28            29             4          0.02842880 -3     0.10000000
# 17  30            31             4          0.19900150 -3     0.32432432
# 18  32            33             1          0.12847550 -3     0.11363636
# 19   0             0             0          0.00000000 -1     1.00000000
# 20  34            35             1          0.01835360 -3     0.11111111
# 21   0             0             0          0.00000000 -1     1.00000000
# 22  36            37             2          0.06074865 -3     0.02702703
# 23  38            39             2          1.19472000 -3     0.10204082
# 24  40            41             2          0.06074865 -3     0.08108108
# 25  42            43             2          0.14174650 -3     0.31182796
# 26  44            45             1          1.19298000 -3     0.07103825
# 27  46            47             1          3.78084000 -3     0.36363636
# 28   0             0             0          0.00000000 -1     0.11764706
# 29  48            49             1          0.05506080 -3     0.07692308
# 30  50            51             1          0.09176820 -3     0.45454545
# ⋮   ⋮             ⋮              ⋮         ⋮           ⋮      ⋮
# 510 526           527            4         0.59700450  -3      9.090909e-02
# 511 528           529            2         0.14174660  -3      3.333333e-01
# 512 530           531            3         0.06500925  -3      1.111111e-01
# 513   0             0            0         0.00000000  -1     -2.775558e-17
# 514   0             0            0         0.00000000  -1      2.500000e-01
# 515   0             0            0         0.00000000  -1      1.764706e-01
# 516   0             0            0         0.00000000  -1     -1.387779e-17
# 517   0             0            0         0.00000000  -1      2.500000e-01
# 518   0             0            0         0.00000000  -1      0.000000e+00
# 519   0             0            0         0.00000000  -1     -1.387779e-17
# 520   0             0            0         0.00000000  -1      0.000000e+00
# 521   0             0            0         0.00000000  -1      0.000000e+00
# 522   0             0            0         0.00000000  -1     -2.775558e-17
# 523 532           533            2         0.10124760  -3      4.285714e-01
# 524   0             0            0         0.00000000  -1      0.000000e+00
# 525   0             0            0         0.00000000  -1     -1.387779e-17
# 526 534           535            4         0.00000000  -3     -1.387779e-17
# 527   0             0            0         0.00000000  -1      2.500000e-01
# 528   0             0            0         0.00000000  -1      0.000000e+00
# 529   0             0            0         0.00000000  -1      4.000000e-01
# 530   0             0            0         0.00000000  -1      1.500000e-01
# 531 536           537            4         0.08528630  -3      6.250000e-02
# 532   0             0            0         0.00000000  -1      2.500000e-01
# 533   0             0            0         0.00000000  -1      6.666667e-01
# 534   0             0            0         0.00000000  -1      0.000000e+00
# 535   0             0            0         0.00000000  -1      0.000000e+00
# 536 538           539            2         0.10124760  -3      1.666667e-01
# 537   0             0            0         0.00000000  -1     -1.387779e-17
# 538   0             0            0         0.00000000  -1      2.500000e-01
# 539   0             0            0         0.00000000  -1      0.000000e+00

# %% [markdown]
# #### Exercise
# - The above example elaborates the definition for the first tree. Try different values of *k* for visualizing other trees in the forest.

# %%
## Fifth tree
getTree(rf2, k=5)
# Out:
#     left daughter right daughter split var split point status prediction
# 1    2             3             4         0.31271650  -3      1.278764e-01
# 2    4             5             3         4.55065000  -3      1.149237e-01
# 3    6             7             2         0.02024955  -3      1.475954e-01
# 4    8             9             3         0.02166975  -3      1.140207e-01
# 5    0             0             0         0.00000000  -1      6.666667e-01
# 6   10            11             3         0.15168850  -3      2.982456e-01
# 7   12            13             3         0.02166975  -3      1.401218e-01
# 8   14            15             2         0.02024955  -3      1.432749e-01
# 9   16            17             1         0.09176820  -3      1.073105e-01
# 10  18            19             3         0.02166975  -3      1.935484e-01
# 11  20            21             3         0.41172550  -3      4.230769e-01
# 12   0             0             0         0.00000000  -1      3.333333e-01
# 13  22            23             4         1.27929500  -3      1.365248e-01
# 14  24            25             4         0.19900150  -3      1.907514e-01
# 15  26            27             1         0.05506080  -3      9.467456e-02
# 16  28            29             3         0.10834900  -3      6.918239e-02
# 17  30            31             1         0.23859650  -3      1.118619e-01
# 18   0             0             0         0.00000000  -1      6.000000e-01
# 19  32            33             4         0.71071950  -3      1.153846e-01
# 20   0             0             0         0.00000000  -1      5.789474e-01
# 21   0             0             0         0.00000000  -1     -1.387779e-17
# 22  34            35             1         0.45883950  -3      1.473118e-01
# 23  36            37             4         3.58202500  -3      8.585859e-02
# 24   0             0             0         0.00000000  -1      1.987578e-01
# 25  38            39             4         0.25585900  -3      8.333333e-02
# 26  40            41             1         0.01835360  -3      1.521739e-01
# 27  42            43             1         0.23859650  -3      7.317073e-02
# 28  44            45             4         0.02842880  -3      5.102041e-02
# 29  46            47             1         0.01835360  -3      9.836066e-02
# 30  48            49             3         0.60675350  -3      1.342513e-01
# ⋮   ⋮             ⋮              ⋮         ⋮           ⋮      ⋮
# 688   0             0            0         0.0000000   -1      5.000000e-01
# 689   0             0            0         0.0000000   -1      1.000000e+00
# 690   0             0            0         0.0000000   -1      0.000000e+00
# 691   0             0            0         0.0000000   -1     -1.387779e-17
# 692 702           703            3         0.2166975   -3      3.750000e-01
# 693   0             0            0         0.0000000   -1      1.000000e+00
# 694   0             0            0         0.0000000   -1      7.500000e-01
# 695 704           705            4         0.3695740   -3     -1.387779e-17
# 696 706           707            2         0.1822455   -3      8.333333e-02
# 697   0             0            0         0.0000000   -1      2.000000e-01
# 698 708           709            3         0.0000000   -3     -1.387779e-17
# 699   0             0            0         0.0000000   -1      0.000000e+00
# 700   0             0            0         0.0000000   -1      2.500000e-01
# 701 710           711            4         0.9950090   -3      1.428571e-01
# 702 712           713            3         0.1516885   -3      4.444444e-01
# 703   0             0            0         0.0000000   -1      2.857143e-01
# 704 714           715            1         0.0000000   -3     -1.387779e-17
# 705   0             0            0         0.0000000   -1      0.000000e+00
# 706   0             0            0         0.0000000   -1      1.428571e-01
# 707   0             0            0         0.0000000   -1      0.000000e+00
# 708   0             0            0         0.0000000   -1      0.000000e+00
# 709   0             0            0         0.0000000   -1      0.000000e+00
# 710 716           717            1         0.0000000   -3      0.000000e+00
# 711   0             0            0         0.0000000   -1      1.000000e+00
# 712   0             0            0         0.0000000   -1      2.500000e-01
# 713   0             0            0         0.0000000   -1      6.000000e-01
# 714   0             0            0         0.0000000   -1      0.000000e+00
# 715   0             0            0         0.0000000   -1      0.000000e+00
# 716   0             0            0         0.0000000   -1      0.000000e+00
# 717   0             0            0         0.0000000   -1      0.000000e+00

# %%
# Multidimensional Scaling (MDS) plot of proximity matrix.

MDSplot(rf2, train_sample$class)
# Out:
# Warning message in RColorBrewer::brewer.pal(nlevs, "Set1"):
# “minimal value for n is 3, returning requested palette with 3 different levels
# ”
# plot without title

# %% [markdown]
# # Notes
#
#   1.  The authors [@Rajagopal2013] construed p300 (a transcription co-activator) binding sites overlapping DNase-I hypersentitive sites and distal to annotated transcription start sites (TSS) as active p300 binding sites representative of enhancers.
#   2. Clusters with presence or absence of H3K36me3 were hypothesized to represent genic and inter-genic enhancers respectively.
#   3. While pre-processing the genomic ranges data if you need to convert WIG file to BED file, you may want to refer to BEDOPS -> wig2bed() function. This is available as a command line utility.
#
# P.S. During intermediary partitioning, if the node has the lowest Gini Index, it becomes leaf node. That will most likely be the case when all remaining non-root nodes have been exhausted, checking for impurity score.
#
# All workshop study material is available at my github page (https://github.com/shauryajauhari).

# %% [markdown]
# The excercises are embedded in the body of the text itself. Please look for the same.
